# %% [markdown]
# # Iris Dataset Analysis
#
# This notebook contains exploratory data analysis of the Iris flower dataset.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scripts.data_loading import load_iris_data
from scripts.visualization import plot_species_comparison, plot_distribution
from scripts.analysis import basic_statistics, group_analysis

# Set visualization style
sns.set(style="whitegrid")

# %%
# Load data
df = load_iris_data()
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# 3     0.0  setosa
# 4     0.0  setosa

# %%
# Basic statistics
stats = basic_statistics(df)
stats
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# Group analysis
group_stats = group_analysis(df)
group_stats
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)  target
# species
# setosa                 0.246     0.0
# versicolor             1.326     1.0
# virginica              2.026     2.0

# %%
# Visualizations
plot_species_comparison(df, 'sepal length (cm)', 'outputs/figures/sepal_length_comparison.png')
plot_distribution(df, 'petal width (cm)', 'outputs/figures/petal_width_distribution.png')

# Display one plot in notebook
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)', hue='species')
plt.title('Sepal vs Petal Length by Species')
plt.show()
